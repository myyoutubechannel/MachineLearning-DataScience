# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x=[3,7,15]
y=[2,6,9]
z = [1,3,5]
w = [5, 8, 2]
plt.plot(x,y)
plt.plot(x,z)
plt.plot(x,w)
plt.title("First demo")
plt.xlabel("X- Axis")
plt.ylabel("Y- Z - W Axis")
plt.legend(["Y","Z","W"])
plt.show()
